# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sinc(x):
    return np.sin(np.pi*x)/(np.pi*x)

# %%
x=np.arange(-7,7, 0.1)

x[:5]
# Out:
# array([-7. , -6.9, -6.8, -6.7, -6.6])

# %%
y=sinc(x)
y[:5]
# Out:
# array([3.89817183e-17, 1.42555311e-02, 2.75143907e-02, 3.84355384e-02,
#        4.58682866e-02])

# %%
plt.plot(y)

# %%
sinc(x[2])
# Out:
# 0.027514390699665745

# %%
plt.plot(np.sinc(x))
